# %%
import xarray as xr
import pandas as pd
import numpy as np


ds_sat_trace_all_diff = xr.open_dataset('TraCE_data/ds_sat_trace_all_diff.nc')
ds_sat_trace_fwf_diff = xr.open_dataset('TraCE_data/ds_sat_trace_fwf_diff.nc')
ds_sat_trace_ghg_diff = xr.open_dataset('TraCE_data/ds_sat_trace_ghg_diff.nc')
ds_sat_trace_orb_diff = xr.open_dataset('TraCE_data/ds_sat_trace_orb_diff.nc')
df_pre = pd.read_csv(r"D:\VScode\Inso_LGMR\inso_data\pre.csv")


import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# %%
from toolbox import significant_test as st
import importlib
importlib.reload(st)


df_pre_TraCE = df_pre.copy()
# crop the df_pre_all to the same time period as ds_sat_trace_all_diff
df_pre_TraCE = df_pre_TraCE[(df_pre_TraCE['age'] >= ds_sat_trace_all_diff.age[0].values) &
                         (df_pre_TraCE['age'] <= ds_sat_trace_all_diff.age[-1].values)]


ccm_out, ran_ccm_list_xy, test_result=st.ccm_significance_test_v2(ds_sat_trace_all_diff, df_pre_TraCE, lat_idx=7, lon_idx=0,
    E=5, 
    tau=-4, 
    n_ran=100, 
    libSizes="10 20 30 40 50 60 70",
    Tp=0,
    sample=10,
    random =True,
    flip_pre= True,
    showPlot=True
)

# %%
from toolbox import significant_map as smap
import importlib
importlib.reload(smap)


df_pre_TraCE = df_pre.copy()
# crop the df_pre_all to the same time period as ds_sat_trace_all_diff
df_pre_TraCE = df_pre_TraCE[(df_pre_TraCE['age'] >= ds_sat_trace_all_diff.age[0].values) &
                         (df_pre_TraCE['age'] <= ds_sat_trace_all_diff.age[-1].values)]

significance_map=smap.global_ccm_significance_map(ds_sat_trace_all_diff, df_pre_TraCE,ds_sat_ens_diff='none',
                                   E=5, tau=-4, Tp=0, libSizes="10 20 30 40 50 60 70 80",
                                   n_ran=10, sample=20, random=True, function='v3', mode='uni', show_figure=True)

import pickle
with open("output/TraCE_all_significance_map_v3.pkl", "wb") as f:
    pickle.dump(significance_map, f)
# Out:
# Processed grid point: lat index=0, lon index=0, significance=(False, False)
# Processed grid point: lat index=0, lon index=1, significance=(False, False)
# Processed grid point: lat index=0, lon index=2, significance=(False, False)
# Processed grid point: lat index=0, lon index=3, significance=(False, False)
# Processed grid point: lat index=0, lon index=4, significance=(False, False)
# Processed grid point: lat index=0, lon index=5, significance=(False, False)
# Processed grid point: lat index=0, lon index=6, significance=(False, False)
# Processed grid point: lat index=0, lon index=7, significance=(False, False)
# Processed grid point: lat index=0, lon index=8, significance=(False, True)
# Processed grid point: lat index=0, lon index=9, significance=(False, False)
# Processed grid point: lat index=0, lon index=10, significance=(False, False)
# Processed grid point: lat index=0, lon index=11, significance=(False, False)
# Processed grid point: lat index=0, lon index=12, significance=(True, False)
# Processed grid point: lat index=0, lon index=13, significance=(False, False)
# Processed grid point: lat index=0, lon index=14, significance=(False, False)
# Processed grid point: lat index=0, lon index=15, significance=(False, False)
# Processed grid point: lat index=0, lon index=16, significance=(False, False)
# Processed grid point: lat index=0, lon index=17, significance=(False, False)
# Processed grid point: lat index=0, lon index=18, significance=(False, False)
# Processed grid point: lat index=0, lon index=19, significance=(False, False)
# Processed grid point: lat index=0, lon index=20, significance=(False, False)
# Processed grid point: lat index=0, lon index=21, significance=(False, False)
# Processed grid point: lat index=0, lon index=22, significance=(False, False)
# Processed grid point: lat index=0, lon index=23, significance=(False, False)
# Processed grid point: lat index=0, lon index=24, significance=(False, False)
# Processed grid point: lat index=0, lon index=25, significance=(False, False)
# Processed grid point: lat index=0, lon index=26, significance=(False, False)
# Processed grid point: lat index=0, lon index=27, significance=(False, False)
# Processed grid point: lat index=0, lon index=28, significance=(False, False)
# Processed grid point: lat index=0, lon index=29, significance=(False, False)
# Processed grid point: lat index=0, lon index=30, significance=(False, False)
# Processed grid point: lat index=0, lon index=31, significance=(False, False)
# Processed grid point: lat index=0, lon index=32, significance=(False, False)
# Processed grid point: lat index=0, lon index=33, significance=(False, False)
# Processed grid point: lat index=0, lon index=34, significance=(False, False)
# Processed grid point: lat index=0, lon index=35, significance=(False, False)
# Processed grid point: lat index=0, lon index=36, significance=(False, False)
# Processed grid point: lat index=0, lon index=37, significance=(False, False)
# Processed grid point: lat index=0, lon index=38, significance=(False, False)
# Processed grid point: lat index=0, lon index=39, significance=(False, False)
# Processed grid point: lat index=0, lon index=40, significance=(False, False)
# Processed grid point: lat index=0, lon index=41, significance=(False, False)
# Processed grid point: lat index=0, lon index=42, significance=(False, False)
# Processed grid point: lat index=0, lon index=43, significance=(False, False)
# Processed grid point: lat index=0, lon index=44, significance=(False, False)
# Processed grid point: lat index=0, lon index=45, significance=(False, False)
# Processed grid point: lat index=0, lon index=46, significance=(False, False)
# Processed grid point: lat index=0, lon index=47, significance=(False, False)
# Processed grid point: lat index=0, lon index=48, significance=(False, False)
# Processed grid point: lat index=0, lon index=49, significance=(False, False)
# Processed grid point: lat index=0, lon index=50, significance=(False, False)
# Processed grid point: lat index=0, lon index=51, significance=(True, False)
# Processed grid point: lat index=0, lon index=52, significance=(False, False)
# Processed grid point: lat index=0, lon index=53, significance=(False, False)
# Processed grid point: lat index=0, lon index=54, significance=(False, False)
# Processed grid point: lat index=0, lon index=55, significance=(False, False)
# Processed grid point: lat index=0, lon index=56, significance=(False, False)
# Processed grid point: lat index=0, lon index=57, significance=(False, False)
# Processed grid point: lat index=0, lon index=58, significance=(True, False)
# Processed grid point: lat index=0, lon index=59, significance=(False, False)
# Processed grid point: lat index=0, lon index=60, significance=(False, False)
# Processed grid point: lat index=0, lon index=61, significance=(False, False)
# Processed grid point: lat index=0, lon index=62, significance=(False, False)
# Processed grid point: lat index=0, lon index=63, significance=(False, True)
# Processed grid point: lat index=0, lon index=64, significance=(False, False)
# Processed grid point: lat index=0, lon index=65, significance=(False, False)
# Processed grid point: lat index=0, lon index=66, significance=(False, False)
# Processed grid point: lat index=0, lon index=67, significance=(False, False)
# Processed grid point: lat index=0, lon index=68, significance=(False, False)
# Processed grid point: lat index=0, lon index=69, significance=(False, False)
# Processed grid point: lat index=0, lon index=70, significance=(False, False)
# Processed grid point: lat index=0, lon index=71, significance=(False, False)
# Processed grid point: lat index=0, lon index=72, significance=(False, False)
# Processed grid point: lat index=0, lon index=73, significance=(False, False)
# Processed grid point: lat index=0, lon index=74, significance=(False, False)
# Processed grid point: lat index=0, lon index=75, significance=(False, False)
# Processed grid point: lat index=0, lon index=76, significance=(False, False)
# Processed grid point: lat index=0, lon index=77, significance=(False, False)
# Processed grid point: lat index=0, lon index=78, significance=(False, False)
# Processed grid point: lat index=0, lon index=79, significance=(False, False)
# Processed grid point: lat index=0, lon index=80, significance=(True, False)
# Processed grid point: lat index=0, lon index=81, significance=(False, False)
# Processed grid point: lat index=0, lon index=82, significance=(False, False)
# Processed grid point: lat index=0, lon index=83, significance=(False, False)
# Processed grid point: lat index=0, lon index=84, significance=(False, False)
# Processed grid point: lat index=0, lon index=85, significance=(False, False)
# Processed grid point: lat index=0, lon index=86, significance=(False, False)
# Processed grid point: lat index=0, lon index=87, significance=(False, False)
# Processed grid point: lat index=0, lon index=88, significance=(False, False)
# Processed grid point: lat index=0, lon index=89, significance=(False, False)
# Processed grid point: lat index=0, lon index=90, significance=(False, False)
# Processed grid point: lat index=0, lon index=91, significance=(False, False)
# Processed grid point: lat index=0, lon index=92, significance=(False, False)
# Processed grid point: lat index=0, lon index=93, significance=(False, False)
# Processed grid point: lat index=0, lon index=94, significance=(False, False)
# Processed grid point: lat index=0, lon index=95, significance=(False, False)
# Processed grid point: lat index=1, lon index=0, significance=(False, False)
# Processed grid point: lat index=1, lon index=1, significance=(False, False)
# Processed grid point: lat index=1, lon index=2, significance=(False, False)
# Processed grid point: lat index=1, lon index=3, significance=(True, False)
# Processed grid point: lat index=1, lon index=4, significance=(False, False)
# Processed grid point: lat index=1, lon index=5, significance=(True, False)
# Processed grid point: lat index=1, lon index=6, significance=(True, False)
# Processed grid point: lat index=1, lon index=7, significance=(True, False)
# Processed grid point: lat index=1, lon index=8, significance=(True, False)
# Processed grid point: lat index=1, lon index=9, significance=(True, False)
# Processed grid point: lat index=1, lon index=10, significance=(True, False)
# Processed grid point: lat index=1, lon index=11, significance=(True, False)
# Processed grid point: lat index=1, lon index=12, significance=(True, False)
# Processed grid point: lat index=1, lon index=13, significance=(False, False)
# Processed grid point: lat index=1, lon index=14, significance=(False, False)
# Processed grid point: lat index=1, lon index=15, significance=(True, False)
# Processed grid point: lat index=1, lon index=16, significance=(False, False)
# Processed grid point: lat index=1, lon index=17, significance=(False, False)
# Processed grid point: lat index=1, lon index=18, significance=(True, False)
# Processed grid point: lat index=1, lon index=19, significance=(True, False)
# Processed grid point: lat index=1, lon index=20, significance=(False, False)
# Processed grid point: lat index=1, lon index=21, significance=(False, False)
# Processed grid point: lat index=1, lon index=22, significance=(False, False)
# Processed grid point: lat index=1, lon index=23, significance=(False, False)
# Processed grid point: lat index=1, lon index=24, significance=(False, False)
# Processed grid point: lat index=1, lon index=25, significance=(False, False)
# Processed grid point: lat index=1, lon index=26, significance=(False, False)
# Processed grid point: lat index=1, lon index=27, significance=(False, False)
# Processed grid point: lat index=1, lon index=28, significance=(False, False)
# Processed grid point: lat index=1, lon index=29, significance=(False, False)
# Processed grid point: lat index=1, lon index=30, significance=(True, False)
# Processed grid point: lat index=1, lon index=31, significance=(False, False)
# Processed grid point: lat index=1, lon index=32, significance=(False, False)
# Processed grid point: lat index=1, lon index=33, significance=(False, False)
# Processed grid point: lat index=1, lon index=34, significance=(False, False)
# Processed grid point: lat index=1, lon index=35, significance=(False, False)
# Processed grid point: lat index=1, lon index=36, significance=(False, False)
# Processed grid point: lat index=1, lon index=37, significance=(True, False)
# Processed grid point: lat index=1, lon index=38, significance=(True, False)
# Processed grid point: lat index=1, lon index=39, significance=(False, False)
# Processed grid point: lat index=1, lon index=40, significance=(False, False)
# Processed grid point: lat index=1, lon index=41, significance=(False, False)
# Processed grid point: lat index=1, lon index=42, significance=(False, False)
# Processed grid point: lat index=1, lon index=43, significance=(True, False)
# Processed grid point: lat index=1, lon index=44, significance=(True, False)
# Processed grid point: lat index=1, lon index=45, significance=(False, False)
# Processed grid point: lat index=1, lon index=46, significance=(True, False)
# Processed grid point: lat index=1, lon index=47, significance=(True, False)
# Processed grid point: lat index=1, lon index=48, significance=(False, False)
# Processed grid point: lat index=1, lon index=49, significance=(True, False)
# Processed grid point: lat index=1, lon index=50, significance=(True, False)
# Processed grid point: lat index=1, lon index=51, significance=(True, False)
# Processed grid point: lat index=1, lon index=52, significance=(True, False)
# Processed grid point: lat index=1, lon index=53, significance=(True, False)
# Processed grid point: lat index=1, lon index=54, significance=(True, False)
# Processed grid point: lat index=1, lon index=55, significance=(True, False)
# Processed grid point: lat index=1, lon index=56, significance=(False, False)
# Processed grid point: lat index=1, lon index=57, significance=(True, False)
# Processed grid point: lat index=1, lon index=58, significance=(True, False)
# Processed grid point: lat index=1, lon index=59, significance=(False, False)
# Processed grid point: lat index=1, lon index=60, significance=(True, False)
# Processed grid point: lat index=1, lon index=61, significance=(True, False)
# Processed grid point: lat index=1, lon index=62, significance=(False, False)
# Processed grid point: lat index=1, lon index=63, significance=(True, False)
# Processed grid point: lat index=1, lon index=64, significance=(True, False)
# Processed grid point: lat index=1, lon index=65, significance=(False, False)
# Processed grid point: lat index=1, lon index=66, significance=(False, False)
# Processed grid point: lat index=1, lon index=67, significance=(False, False)
# Processed grid point: lat index=1, lon index=68, significance=(False, False)
# Processed grid point: lat index=1, lon index=69, significance=(False, False)
# Processed grid point: lat index=1, lon index=70, significance=(True, False)
# Processed grid point: lat index=1, lon index=71, significance=(False, False)
# Processed grid point: lat index=1, lon index=72, significance=(False, False)
# Processed grid point: lat index=1, lon index=73, significance=(False, False)
# Processed grid point: lat index=1, lon index=74, significance=(False, False)
# Processed grid point: lat index=1, lon index=75, significance=(False, False)
# Processed grid point: lat index=1, lon index=76, significance=(True, False)
# Processed grid point: lat index=1, lon index=77, significance=(True, False)
# Processed grid point: lat index=1, lon index=78, significance=(True, False)
# Processed grid point: lat index=1, lon index=79, significance=(True, False)
# Processed grid point: lat index=1, lon index=80, significance=(False, False)
# Processed grid point: lat index=1, lon index=81, significance=(True, False)
# Processed grid point: lat index=1, lon index=82, significance=(False, False)
# Processed grid point: lat index=1, lon index=83, significance=(False, False)
# Processed grid point: lat index=1, lon index=84, significance=(False, False)
# Processed grid point: lat index=1, lon index=85, significance=(False, False)
# Processed grid point: lat index=1, lon index=86, significance=(False, False)
# Processed grid point: lat index=1, lon index=87, significance=(False, False)
# Processed grid point: lat index=1, lon index=88, significance=(False, False)
# Processed grid point: lat index=1, lon index=89, significance=(True, False)
# Processed grid point: lat index=1, lon index=90, significance=(False, False)
# Processed grid point: lat index=1, lon index=91, significance=(True, False)
# Processed grid point: lat index=1, lon index=92, significance=(False, False)
# Processed grid point: lat index=1, lon index=93, significance=(False, False)
# Processed grid point: lat index=1, lon index=94, significance=(False, False)
# Processed grid point: lat index=1, lon index=95, significance=(False, False)
# Processed grid point: lat index=2, lon index=0, significance=(True, False)
# Processed grid point: lat index=2, lon index=1, significance=(True, False)
# Processed grid point: lat index=2, lon index=2, significance=(True, False)
# Processed grid point: lat index=2, lon index=3, significance=(True, False)
# Processed grid point: lat index=2, lon index=4, significance=(True, False)
# Processed grid point: lat index=2, lon index=5, significance=(True, False)
# Processed grid point: lat index=2, lon index=6, significance=(True, False)
# Processed grid point: lat index=2, lon index=7, significance=(True, False)
# Processed grid point: lat index=2, lon index=8, significance=(True, False)
# Processed grid point: lat index=2, lon index=9, significance=(True, False)
# Processed grid point: lat index=2, lon index=10, significance=(True, False)
# Processed grid point: lat index=2, lon index=11, significance=(True, False)
# Processed grid point: lat index=2, lon index=12, significance=(True, False)
# Processed grid point: lat index=2, lon index=13, significance=(True, False)
# Processed grid point: lat index=2, lon index=14, significance=(True, False)
# Processed grid point: lat index=2, lon index=15, significance=(True, False)
# Processed grid point: lat index=2, lon index=16, significance=(False, False)
# Processed grid point: lat index=2, lon index=17, significance=(False, False)
# Processed grid point: lat index=2, lon index=18, significance=(False, False)
# Processed grid point: lat index=2, lon index=19, significance=(True, False)
# Processed grid point: lat index=2, lon index=20, significance=(False, False)
# Processed grid point: lat index=2, lon index=21, significance=(False, False)
# Processed grid point: lat index=2, lon index=22, significance=(False, False)
# Processed grid point: lat index=2, lon index=23, significance=(False, False)
# Processed grid point: lat index=2, lon index=24, significance=(True, False)
# Processed grid point: lat index=2, lon index=25, significance=(False, False)
# Processed grid point: lat index=2, lon index=26, significance=(False, False)
# Processed grid point: lat index=2, lon index=27, significance=(True, False)
# Processed grid point: lat index=2, lon index=28, significance=(False, False)
# Processed grid point: lat index=2, lon index=29, significance=(True, False)
# Processed grid point: lat index=2, lon index=30, significance=(False, False)
# Processed grid point: lat index=2, lon index=31, significance=(False, False)
# Processed grid point: lat index=2, lon index=32, significance=(False, False)
# Processed grid point: lat index=2, lon index=33, significance=(True, False)
# Processed grid point: lat index=2, lon index=34, significance=(True, False)
# Processed grid point: lat index=2, lon index=35, significance=(True, False)
# Processed grid point: lat index=2, lon index=36, significance=(True, False)
# Processed grid point: lat index=2, lon index=37, significance=(True, False)
# Processed grid point: lat index=2, lon index=38, significance=(True, False)
# Processed grid point: lat index=2, lon index=39, significance=(False, False)
# Processed grid point: lat index=2, lon index=40, significance=(True, False)
# Processed grid point: lat index=2, lon index=41, significance=(True, False)
# Processed grid point: lat index=2, lon index=42, significance=(True, False)
# Processed grid point: lat index=2, lon index=43, significance=(True, False)
# Processed grid point: lat index=2, lon index=44, significance=(True, False)
# Processed grid point: lat index=2, lon index=45, significance=(False, False)
# Processed grid point: lat index=2, lon index=46, significance=(True, False)
# Processed grid point: lat index=2, lon index=47, significance=(False, False)
# Processed grid point: lat index=2, lon index=48, significance=(True, False)
# Processed grid point: lat index=2, lon index=49, significance=(True, False)
# Processed grid point: lat index=2, lon index=50, significance=(False, False)
# Processed grid point: lat index=2, lon index=51, significance=(True, False)
# Processed grid point: lat index=2, lon index=52, significance=(True, False)
# Processed grid point: lat index=2, lon index=53, significance=(False, False)
# Processed grid point: lat index=2, lon index=54, significance=(True, False)
# Processed grid point: lat index=2, lon index=55, significance=(True, False)
# Processed grid point: lat index=2, lon index=56, significance=(True, False)
# Processed grid point: lat index=2, lon index=57, significance=(True, False)
# Processed grid point: lat index=2, lon index=58, significance=(True, False)
# Processed grid point: lat index=2, lon index=59, significance=(True, False)
# Processed grid point: lat index=2, lon index=60, significance=(False, False)
# Processed grid point: lat index=2, lon index=61, significance=(True, False)
# Processed grid point: lat index=2, lon index=62, significance=(True, False)
# Processed grid point: lat index=2, lon index=63, significance=(False, False)
# Processed grid point: lat index=2, lon index=64, significance=(True, False)
# Processed grid point: lat index=2, lon index=65, significance=(False, False)
# Processed grid point: lat index=2, lon index=66, significance=(False, False)
# Processed grid point: lat index=2, lon index=67, significance=(False, False)
# Processed grid point: lat index=2, lon index=68, significance=(True, False)
# Processed grid point: lat index=2, lon index=69, significance=(True, True)
# Processed grid point: lat index=2, lon index=70, significance=(False, False)
# Processed grid point: lat index=2, lon index=71, significance=(False, False)
# Processed grid point: lat index=2, lon index=72, significance=(False, False)
# Processed grid point: lat index=2, lon index=73, significance=(False, False)
# Processed grid point: lat index=2, lon index=74, significance=(True, False)
# Processed grid point: lat index=2, lon index=75, significance=(False, False)
# Processed grid point: lat index=2, lon index=76, significance=(True, False)
# Processed grid point: lat index=2, lon index=77, significance=(True, False)
# Processed grid point: lat index=2, lon index=78, significance=(False, False)
# Processed grid point: lat index=2, lon index=79, significance=(False, False)
# Processed grid point: lat index=2, lon index=80, significance=(True, False)
# Processed grid point: lat index=2, lon index=81, significance=(True, False)
# Processed grid point: lat index=2, lon index=82, significance=(True, False)
# Processed grid point: lat index=2, lon index=83, significance=(False, False)
# Processed grid point: lat index=2, lon index=84, significance=(True, False)
# Processed grid point: lat index=2, lon index=85, significance=(True, False)
# Processed grid point: lat index=2, lon index=86, significance=(False, False)
# Processed grid point: lat index=2, lon index=87, significance=(False, False)
# Processed grid point: lat index=2, lon index=88, significance=(True, False)
# Processed grid point: lat index=2, lon index=89, significance=(False, False)
# Processed grid point: lat index=2, lon index=90, significance=(False, False)
# Processed grid point: lat index=2, lon index=91, significance=(True, False)
# Processed grid point: lat index=2, lon index=92, significance=(False, False)
# Processed grid point: lat index=2, lon index=93, significance=(True, False)
# Processed grid point: lat index=2, lon index=94, significance=(True, False)
# Processed grid point: lat index=2, lon index=95, significance=(True, False)
# Processed grid point: lat index=3, lon index=0, significance=(True, False)
# Processed grid point: lat index=3, lon index=1, significance=(True, False)
# Processed grid point: lat index=3, lon index=2, significance=(True, False)
# Processed grid point: lat index=3, lon index=3, significance=(False, False)
# Processed grid point: lat index=3, lon index=4, significance=(True, False)
# Processed grid point: lat index=3, lon index=5, significance=(True, False)
# Processed grid point: lat index=3, lon index=6, significance=(True, False)
# Processed grid point: lat index=3, lon index=7, significance=(False, False)
# Processed grid point: lat index=3, lon index=8, significance=(False, False)
# Processed grid point: lat index=3, lon index=9, significance=(True, False)
# Processed grid point: lat index=3, lon index=10, significance=(False, False)
# Processed grid point: lat index=3, lon index=11, significance=(True, False)
# Processed grid point: lat index=3, lon index=12, significance=(True, False)
# Processed grid point: lat index=3, lon index=13, significance=(True, False)
# Processed grid point: lat index=3, lon index=14, significance=(True, False)
# Processed grid point: lat index=3, lon index=15, significance=(True, False)
# Processed grid point: lat index=3, lon index=16, significance=(True, False)
# Processed grid point: lat index=3, lon index=17, significance=(True, False)
# Processed grid point: lat index=3, lon index=18, significance=(True, False)
# Processed grid point: lat index=3, lon index=19, significance=(False, False)
# Processed grid point: lat index=3, lon index=20, significance=(True, False)
# Processed grid point: lat index=3, lon index=21, significance=(False, False)
# Processed grid point: lat index=3, lon index=22, significance=(False, False)
# Processed grid point: lat index=3, lon index=23, significance=(True, False)
# Processed grid point: lat index=3, lon index=24, significance=(False, False)
# Processed grid point: lat index=3, lon index=25, significance=(True, False)
# Processed grid point: lat index=3, lon index=26, significance=(False, False)
# Processed grid point: lat index=3, lon index=27, significance=(False, False)
# Processed grid point: lat index=3, lon index=28, significance=(True, False)
# Processed grid point: lat index=3, lon index=29, significance=(False, False)
# Processed grid point: lat index=3, lon index=30, significance=(False, False)
# Processed grid point: lat index=3, lon index=31, significance=(True, False)
# Processed grid point: lat index=3, lon index=32, significance=(True, False)
# Processed grid point: lat index=3, lon index=33, significance=(True, False)
# Processed grid point: lat index=3, lon index=34, significance=(False, False)
# Processed grid point: lat index=3, lon index=35, significance=(True, False)
# Processed grid point: lat index=3, lon index=36, significance=(False, False)
# Processed grid point: lat index=3, lon index=37, significance=(False, False)
# Processed grid point: lat index=3, lon index=38, significance=(False, False)
# Processed grid point: lat index=3, lon index=39, significance=(False, False)
# Processed grid point: lat index=3, lon index=40, significance=(False, False)
# Processed grid point: lat index=3, lon index=41, significance=(False, False)
# Processed grid point: lat index=3, lon index=42, significance=(False, False)
# Processed grid point: lat index=3, lon index=43, significance=(True, False)
# Processed grid point: lat index=3, lon index=44, significance=(True, False)
# Processed grid point: lat index=3, lon index=45, significance=(False, False)
# Processed grid point: lat index=3, lon index=46, significance=(False, False)
# Processed grid point: lat index=3, lon index=47, significance=(False, False)
# Processed grid point: lat index=3, lon index=48, significance=(True, False)
# Processed grid point: lat index=3, lon index=49, significance=(True, False)
# Processed grid point: lat index=3, lon index=50, significance=(False, False)
# Processed grid point: lat index=3, lon index=51, significance=(True, False)
# Processed grid point: lat index=3, lon index=52, significance=(False, False)
# Processed grid point: lat index=3, lon index=53, significance=(False, False)
# Processed grid point: lat index=3, lon index=54, significance=(False, False)
# Processed grid point: lat index=3, lon index=55, significance=(False, False)
# Processed grid point: lat index=3, lon index=56, significance=(True, False)
# Processed grid point: lat index=3, lon index=57, significance=(False, False)
# Processed grid point: lat index=3, lon index=58, significance=(False, False)
# Processed grid point: lat index=3, lon index=59, significance=(False, False)
# Processed grid point: lat index=3, lon index=60, significance=(True, False)
# Processed grid point: lat index=3, lon index=61, significance=(True, False)
# Processed grid point: lat index=3, lon index=62, significance=(True, False)
# Processed grid point: lat index=3, lon index=63, significance=(True, False)
# Processed grid point: lat index=3, lon index=64, significance=(False, False)
# Processed grid point: lat index=3, lon index=65, significance=(True, False)
# Processed grid point: lat index=3, lon index=66, significance=(False, False)
# Processed grid point: lat index=3, lon index=67, significance=(False, False)
# Processed grid point: lat index=3, lon index=68, significance=(False, False)
# Processed grid point: lat index=3, lon index=69, significance=(False, False)
# Processed grid point: lat index=3, lon index=70, significance=(False, False)
# Processed grid point: lat index=3, lon index=71, significance=(True, False)
# Processed grid point: lat index=3, lon index=72, significance=(True, False)
# Processed grid point: lat index=3, lon index=73, significance=(False, False)
# Processed grid point: lat index=3, lon index=74, significance=(True, False)
# Processed grid point: lat index=3, lon index=75, significance=(True, False)
# Processed grid point: lat index=3, lon index=76, significance=(True, False)
# Processed grid point: lat index=3, lon index=77, significance=(False, False)
# Processed grid point: lat index=3, lon index=78, significance=(True, False)
# Processed grid point: lat index=3, lon index=79, significance=(True, False)
# Processed grid point: lat index=3, lon index=80, significance=(True, False)
# Processed grid point: lat index=3, lon index=81, significance=(False, False)
# Processed grid point: lat index=3, lon index=82, significance=(False, False)
# Processed grid point: lat index=3, lon index=83, significance=(True, False)
# Processed grid point: lat index=3, lon index=84, significance=(False, False)
# Processed grid point: lat index=3, lon index=85, significance=(True, False)
# Processed grid point: lat index=3, lon index=86, significance=(True, False)
# Processed grid point: lat index=3, lon index=87, significance=(True, False)
# Processed grid point: lat index=3, lon index=88, significance=(True, False)
# Processed grid point: lat index=3, lon index=89, significance=(False, False)
# Processed grid point: lat index=3, lon index=90, significance=(False, False)
# Processed grid point: lat index=3, lon index=91, significance=(False, False)
# Processed grid point: lat index=3, lon index=92, significance=(False, False)
# Processed grid point: lat index=3, lon index=93, significance=(True, False)
# Processed grid point: lat index=3, lon index=94, significance=(True, False)
# Processed grid point: lat index=3, lon index=95, significance=(True, False)
# Processed grid point: lat index=4, lon index=0, significance=(False, False)
# Processed grid point: lat index=4, lon index=1, significance=(True, False)
# Processed grid point: lat index=4, lon index=2, significance=(True, False)
# Processed grid point: lat index=4, lon index=3, significance=(True, False)
# Processed grid point: lat index=4, lon index=4, significance=(True, False)
# Processed grid point: lat index=4, lon index=5, significance=(False, False)
# Processed grid point: lat index=4, lon index=6, significance=(False, False)
# Processed grid point: lat index=4, lon index=7, significance=(False, False)
# Processed grid point: lat index=4, lon index=8, significance=(False, False)
# Processed grid point: lat index=4, lon index=9, significance=(False, False)
# Processed grid point: lat index=4, lon index=10, significance=(False, False)
# Processed grid point: lat index=4, lon index=11, significance=(False, False)
# Processed grid point: lat index=4, lon index=12, significance=(True, False)
# Processed grid point: lat index=4, lon index=13, significance=(False, False)
# Processed grid point: lat index=4, lon index=14, significance=(True, False)
# Processed grid point: lat index=4, lon index=15, significance=(False, False)
# Processed grid point: lat index=4, lon index=16, significance=(False, False)
# Processed grid point: lat index=4, lon index=17, significance=(False, False)
# Processed grid point: lat index=4, lon index=18, significance=(False, False)
# Processed grid point: lat index=4, lon index=19, significance=(False, False)
# Processed grid point: lat index=4, lon index=20, significance=(True, False)
# Processed grid point: lat index=4, lon index=21, significance=(True, False)
# Processed grid point: lat index=4, lon index=22, significance=(True, False)
# Processed grid point: lat index=4, lon index=23, significance=(False, False)
# Processed grid point: lat index=4, lon index=24, significance=(False, False)
# Processed grid point: lat index=4, lon index=25, significance=(False, False)
# Processed grid point: lat index=4, lon index=26, significance=(False, False)
# Processed grid point: lat index=4, lon index=27, significance=(False, False)
# Processed grid point: lat index=4, lon index=28, significance=(False, False)
# Processed grid point: lat index=4, lon index=29, significance=(False, False)
# Processed grid point: lat index=4, lon index=30, significance=(True, False)
# Processed grid point: lat index=4, lon index=31, significance=(False, False)
# Processed grid point: lat index=4, lon index=32, significance=(False, False)
# Processed grid point: lat index=4, lon index=33, significance=(False, False)
# Processed grid point: lat index=4, lon index=34, significance=(False, False)
# Processed grid point: lat index=4, lon index=35, significance=(False, False)
# Processed grid point: lat index=4, lon index=36, significance=(False, False)
# Processed grid point: lat index=4, lon index=37, significance=(False, False)
# Processed grid point: lat index=4, lon index=38, significance=(False, False)
# Processed grid point: lat index=4, lon index=39, significance=(True, False)
# Processed grid point: lat index=4, lon index=40, significance=(False, False)
# Processed grid point: lat index=4, lon index=41, significance=(True, False)
# Processed grid point: lat index=4, lon index=42, significance=(True, False)
# Processed grid point: lat index=4, lon index=43, significance=(False, False)
# Processed grid point: lat index=4, lon index=44, significance=(False, False)
# Processed grid point: lat index=4, lon index=45, significance=(False, False)
# Processed grid point: lat index=4, lon index=46, significance=(True, False)
# Processed grid point: lat index=4, lon index=47, significance=(True, False)
# Processed grid point: lat index=4, lon index=48, significance=(False, False)
# Processed grid point: lat index=4, lon index=49, significance=(False, False)
# Processed grid point: lat index=4, lon index=50, significance=(False, False)
# Processed grid point: lat index=4, lon index=51, significance=(False, False)
# Processed grid point: lat index=4, lon index=52, significance=(False, False)
# Processed grid point: lat index=4, lon index=53, significance=(False, True)
# Processed grid point: lat index=4, lon index=54, significance=(False, False)
# Processed grid point: lat index=4, lon index=55, significance=(False, False)
# Processed grid point: lat index=4, lon index=56, significance=(True, False)
# Processed grid point: lat index=4, lon index=57, significance=(False, True)
# Processed grid point: lat index=4, lon index=58, significance=(False, False)
# Processed grid point: lat index=4, lon index=59, significance=(False, False)
# Processed grid point: lat index=4, lon index=60, significance=(False, False)
# Processed grid point: lat index=4, lon index=61, significance=(False, False)
# Processed grid point: lat index=4, lon index=62, significance=(True, False)
# Processed grid point: lat index=4, lon index=63, significance=(True, False)
# Processed grid point: lat index=4, lon index=64, significance=(True, False)
# Processed grid point: lat index=4, lon index=65, significance=(True, False)
# Processed grid point: lat index=4, lon index=66, significance=(True, False)
# Processed grid point: lat index=4, lon index=67, significance=(True, False)
# Processed grid point: lat index=4, lon index=68, significance=(True, False)
# Processed grid point: lat index=4, lon index=69, significance=(False, False)
# Processed grid point: lat index=4, lon index=70, significance=(True, False)
# Processed grid point: lat index=4, lon index=71, significance=(True, False)
# Processed grid point: lat index=4, lon index=72, significance=(True, False)
# Processed grid point: lat index=4, lon index=73, significance=(True, False)
# Processed grid point: lat index=4, lon index=74, significance=(True, False)
# Processed grid point: lat index=4, lon index=75, significance=(True, False)
# Processed grid point: lat index=4, lon index=76, significance=(True, False)
# Processed grid point: lat index=4, lon index=77, significance=(False, False)
# Processed grid point: lat index=4, lon index=78, significance=(False, False)
# Processed grid point: lat index=4, lon index=79, significance=(False, False)
# Processed grid point: lat index=4, lon index=80, significance=(True, False)
# Processed grid point: lat index=4, lon index=81, significance=(True, False)
# Processed grid point: lat index=4, lon index=82, significance=(True, False)
# Processed grid point: lat index=4, lon index=83, significance=(False, False)
# Processed grid point: lat index=4, lon index=84, significance=(True, False)
# Processed grid point: lat index=4, lon index=85, significance=(True, False)
# Processed grid point: lat index=4, lon index=86, significance=(False, False)
# Processed grid point: lat index=4, lon index=87, significance=(False, False)
# Processed grid point: lat index=4, lon index=88, significance=(False, False)
# Processed grid point: lat index=4, lon index=89, significance=(False, False)
# Processed grid point: lat index=4, lon index=90, significance=(False, False)
# Processed grid point: lat index=4, lon index=91, significance=(False, False)
# Processed grid point: lat index=4, lon index=92, significance=(False, False)
# Processed grid point: lat index=4, lon index=93, significance=(False, False)
# Processed grid point: lat index=4, lon index=94, significance=(True, False)
# Processed grid point: lat index=4, lon index=95, significance=(False, False)
# Processed grid point: lat index=5, lon index=0, significance=(True, False)
# Processed grid point: lat index=5, lon index=1, significance=(True, False)
# Processed grid point: lat index=5, lon index=2, significance=(True, False)
# Processed grid point: lat index=5, lon index=3, significance=(False, False)
# Processed grid point: lat index=5, lon index=4, significance=(False, False)
# Processed grid point: lat index=5, lon index=5, significance=(True, False)
# Processed grid point: lat index=5, lon index=6, significance=(True, False)
# Processed grid point: lat index=5, lon index=7, significance=(True, False)
# Processed grid point: lat index=5, lon index=8, significance=(False, False)
# Processed grid point: lat index=5, lon index=9, significance=(False, False)
# Processed grid point: lat index=5, lon index=10, significance=(True, False)
# Processed grid point: lat index=5, lon index=11, significance=(True, False)
# Processed grid point: lat index=5, lon index=12, significance=(False, False)
# Processed grid point: lat index=5, lon index=13, significance=(False, False)
# Processed grid point: lat index=5, lon index=14, significance=(False, False)
# Processed grid point: lat index=5, lon index=15, significance=(False, False)
# Processed grid point: lat index=5, lon index=16, significance=(True, False)
# Processed grid point: lat index=5, lon index=17, significance=(False, False)
# Processed grid point: lat index=5, lon index=18, significance=(True, False)
# Processed grid point: lat index=5, lon index=19, significance=(True, False)
# Processed grid point: lat index=5, lon index=20, significance=(False, False)
# Processed grid point: lat index=5, lon index=21, significance=(False, False)
# Processed grid point: lat index=5, lon index=22, significance=(True, False)
# Processed grid point: lat index=5, lon index=23, significance=(False, False)
# Processed grid point: lat index=5, lon index=24, significance=(False, False)
# Processed grid point: lat index=5, lon index=25, significance=(False, False)
# Processed grid point: lat index=5, lon index=26, significance=(False, False)
# Processed grid point: lat index=5, lon index=27, significance=(False, False)
# Processed grid point: lat index=5, lon index=28, significance=(True, False)
# Processed grid point: lat index=5, lon index=29, significance=(False, False)
# Processed grid point: lat index=5, lon index=30, significance=(True, False)
# Processed grid point: lat index=5, lon index=31, significance=(False, False)
# Processed grid point: lat index=5, lon index=32, significance=(False, False)
# Processed grid point: lat index=5, lon index=33, significance=(True, False)
# Processed grid point: lat index=5, lon index=34, significance=(False, False)
# Processed grid point: lat index=5, lon index=35, significance=(False, True)
# Processed grid point: lat index=5, lon index=36, significance=(True, False)
# Processed grid point: lat index=5, lon index=37, significance=(False, False)
# Processed grid point: lat index=5, lon index=38, significance=(False, False)
# Processed grid point: lat index=5, lon index=39, significance=(True, False)
# Processed grid point: lat index=5, lon index=40, significance=(False, False)
# Processed grid point: lat index=5, lon index=41, significance=(False, False)
# Processed grid point: lat index=5, lon index=42, significance=(False, False)
# Processed grid point: lat index=5, lon index=43, significance=(False, False)
# Processed grid point: lat index=5, lon index=44, significance=(True, False)
# Processed grid point: lat index=5, lon index=45, significance=(True, False)
# Processed grid point: lat index=5, lon index=46, significance=(False, False)
# Processed grid point: lat index=5, lon index=47, significance=(False, False)
# Processed grid point: lat index=5, lon index=48, significance=(False, False)
# Processed grid point: lat index=5, lon index=49, significance=(False, False)
# Processed grid point: lat index=5, lon index=50, significance=(False, False)
# Processed grid point: lat index=5, lon index=51, significance=(False, False)
# Processed grid point: lat index=5, lon index=52, significance=(False, False)
# Processed grid point: lat index=5, lon index=53, significance=(True, False)
# Processed grid point: lat index=5, lon index=54, significance=(False, False)
# Processed grid point: lat index=5, lon index=55, significance=(False, False)
# Processed grid point: lat index=5, lon index=56, significance=(False, True)
# Processed grid point: lat index=5, lon index=57, significance=(False, False)
# Processed grid point: lat index=5, lon index=58, significance=(False, False)
# Processed grid point: lat index=5, lon index=59, significance=(False, False)
# Processed grid point: lat index=5, lon index=60, significance=(False, False)
# Processed grid point: lat index=5, lon index=61, significance=(False, False)
# Processed grid point: lat index=5, lon index=62, significance=(False, False)
# Processed grid point: lat index=5, lon index=63, significance=(False, False)
# Processed grid point: lat index=5, lon index=64, significance=(False, False)
# Processed grid point: lat index=5, lon index=65, significance=(False, False)
# Processed grid point: lat index=5, lon index=66, significance=(True, False)
# Processed grid point: lat index=5, lon index=67, significance=(False, False)
# Processed grid point: lat index=5, lon index=68, significance=(True, False)
# Processed grid point: lat index=5, lon index=69, significance=(True, False)
# Processed grid point: lat index=5, lon index=70, significance=(True, False)
# Processed grid point: lat index=5, lon index=71, significance=(True, False)
# Processed grid point: lat index=5, lon index=72, significance=(True, False)
# Processed grid point: lat index=5, lon index=73, significance=(True, False)
# Processed grid point: lat index=5, lon index=74, significance=(True, False)
# Processed grid point: lat index=5, lon index=75, significance=(True, False)
# Processed grid point: lat index=5, lon index=76, significance=(True, False)
# Processed grid point: lat index=5, lon index=77, significance=(True, False)
# Processed grid point: lat index=5, lon index=78, significance=(True, False)
# Processed grid point: lat index=5, lon index=79, significance=(False, False)
# Processed grid point: lat index=5, lon index=80, significance=(False, False)
# Processed grid point: lat index=5, lon index=81, significance=(False, False)
# Processed grid point: lat index=5, lon index=82, significance=(False, False)
# Processed grid point: lat index=5, lon index=83, significance=(False, False)
# Processed grid point: lat index=5, lon index=84, significance=(False, False)
# Processed grid point: lat index=5, lon index=85, significance=(False, False)
# Processed grid point: lat index=5, lon index=86, significance=(False, False)
# Processed grid point: lat index=5, lon index=87, significance=(False, False)
# Processed grid point: lat index=5, lon index=88, significance=(False, False)
# Processed grid point: lat index=5, lon index=89, significance=(False, False)
# Processed grid point: lat index=5, lon index=90, significance=(True, False)
# Processed grid point: lat index=5, lon index=91, significance=(False, False)
# Processed grid point: lat index=5, lon index=92, significance=(True, False)
# Processed grid point: lat index=5, lon index=93, significance=(False, False)
# Processed grid point: lat index=5, lon index=94, significance=(False, False)
# Processed grid point: lat index=5, lon index=95, significance=(True, False)
# Processed grid point: lat index=6, lon index=0, significance=(False, False)
# Processed grid point: lat index=6, lon index=1, significance=(True, False)
# Processed grid point: lat index=6, lon index=2, significance=(False, False)
# Processed grid point: lat index=6, lon index=3, significance=(False, False)
# Processed grid point: lat index=6, lon index=4, significance=(False, False)
# Processed grid point: lat index=6, lon index=5, significance=(False, False)
# Processed grid point: lat index=6, lon index=6, significance=(False, False)
# Processed grid point: lat index=6, lon index=7, significance=(False, False)
# Processed grid point: lat index=6, lon index=8, significance=(False, False)
# Processed grid point: lat index=6, lon index=9, significance=(False, False)
# Processed grid point: lat index=6, lon index=10, significance=(True, False)
# Processed grid point: lat index=6, lon index=11, significance=(True, False)
# Processed grid point: lat index=6, lon index=12, significance=(False, False)
# Processed grid point: lat index=6, lon index=13, significance=(True, False)
# Processed grid point: lat index=6, lon index=14, significance=(True, False)
# Processed grid point: lat index=6, lon index=15, significance=(True, False)
# Processed grid point: lat index=6, lon index=16, significance=(False, False)
# Processed grid point: lat index=6, lon index=17, significance=(True, False)
# Processed grid point: lat index=6, lon index=18, significance=(False, False)
# Processed grid point: lat index=6, lon index=19, significance=(False, False)
# Processed grid point: lat index=6, lon index=20, significance=(True, False)
# Processed grid point: lat index=6, lon index=21, significance=(False, False)
# Processed grid point: lat index=6, lon index=22, significance=(False, False)
# Processed grid point: lat index=6, lon index=23, significance=(True, False)
# Processed grid point: lat index=6, lon index=24, significance=(False, False)
# Processed grid point: lat index=6, lon index=25, significance=(False, False)
# Processed grid point: lat index=6, lon index=26, significance=(False, False)
# Processed grid point: lat index=6, lon index=27, significance=(True, False)
# Processed grid point: lat index=6, lon index=28, significance=(False, False)
# Processed grid point: lat index=6, lon index=29, significance=(False, False)
# Processed grid point: lat index=6, lon index=30, significance=(True, False)
# Processed grid point: lat index=6, lon index=31, significance=(False, False)
# Processed grid point: lat index=6, lon index=32, significance=(False, False)
# Processed grid point: lat index=6, lon index=33, significance=(False, False)
# Processed grid point: lat index=6, lon index=34, significance=(False, False)
# Processed grid point: lat index=6, lon index=35, significance=(False, False)
# Processed grid point: lat index=6, lon index=36, significance=(False, False)
# Processed grid point: lat index=6, lon index=37, significance=(False, False)
# Processed grid point: lat index=6, lon index=38, significance=(False, False)
# Processed grid point: lat index=6, lon index=39, significance=(True, False)
# Processed grid point: lat index=6, lon index=40, significance=(False, False)
# Processed grid point: lat index=6, lon index=41, significance=(False, False)
# Processed grid point: lat index=6, lon index=42, significance=(True, False)
# Processed grid point: lat index=6, lon index=43, significance=(False, False)
# Processed grid point: lat index=6, lon index=44, significance=(False, False)
# Processed grid point: lat index=6, lon index=45, significance=(False, False)
# Processed grid point: lat index=6, lon index=46, significance=(True, False)
# Processed grid point: lat index=6, lon index=47, significance=(False, False)
# Processed grid point: lat index=6, lon index=48, significance=(False, False)
# Processed grid point: lat index=6, lon index=49, significance=(False, False)
# Processed grid point: lat index=6, lon index=50, significance=(False, False)
# ...
# Processed grid point: lat index=45, lon index=80, significance=(True, False)
# Processed grid point: lat index=45, lon index=81, significance=(False, False)
# Processed grid point: lat index=45, lon index=82, significance=(True, False)
# Processed grid point: lat index=45, lon index=83, significance=(True, False)
# Processed grid point: lat index=45, lon index=84, significance=(True, False)
# Processed grid point: lat index=45, lon index=85, significance=(True, False)
# Processed grid point: lat index=45, lon index=86, significance=(True, False)
# Processed grid point: lat index=45, lon index=87, significance=(False, False)
# Processed grid point: lat index=45, lon index=88, significance=(True, False)
# Processed grid point: lat index=45, lon index=89, significance=(True, False)
# Processed grid point: lat index=45, lon index=90, significance=(True, False)
# Processed grid point: lat index=45, lon index=91, significance=(True, False)
# Processed grid point: lat index=45, lon index=92, significance=(True, False)
# Processed grid point: lat index=45, lon index=93, significance=(True, False)
# Processed grid point: lat index=45, lon index=94, significance=(True, False)
# Processed grid point: lat index=45, lon index=95, significance=(True, False)
# Processed grid point: lat index=46, lon index=0, significance=(True, False)
# Processed grid point: lat index=46, lon index=1, significance=(True, False)
# Processed grid point: lat index=46, lon index=2, significance=(True, False)
# Processed grid point: lat index=46, lon index=3, significance=(True, False)
# Processed grid point: lat index=46, lon index=4, significance=(True, False)
# Processed grid point: lat index=46, lon index=5, significance=(True, False)
# Processed grid point: lat index=46, lon index=6, significance=(True, True)
# Processed grid point: lat index=46, lon index=7, significance=(True, False)
# Processed grid point: lat index=46, lon index=8, significance=(True, False)
# Processed grid point: lat index=46, lon index=9, significance=(True, False)
# Processed grid point: lat index=46, lon index=10, significance=(True, False)
# Processed grid point: lat index=46, lon index=11, significance=(True, False)
# Processed grid point: lat index=46, lon index=12, significance=(True, False)
# Processed grid point: lat index=46, lon index=13, significance=(True, False)
# Processed grid point: lat index=46, lon index=14, significance=(True, True)
# Processed grid point: lat index=46, lon index=15, significance=(True, False)
# Processed grid point: lat index=46, lon index=16, significance=(True, False)
# Processed grid point: lat index=46, lon index=17, significance=(True, True)
# Processed grid point: lat index=46, lon index=18, significance=(True, False)
# Processed grid point: lat index=46, lon index=19, significance=(True, False)
# Processed grid point: lat index=46, lon index=20, significance=(False, False)
# Processed grid point: lat index=46, lon index=21, significance=(True, False)
# Processed grid point: lat index=46, lon index=22, significance=(False, False)
# Processed grid point: lat index=46, lon index=23, significance=(True, False)
# Processed grid point: lat index=46, lon index=24, significance=(False, True)
# Processed grid point: lat index=46, lon index=25, significance=(False, True)
# Processed grid point: lat index=46, lon index=26, significance=(False, False)
# Processed grid point: lat index=46, lon index=27, significance=(True, False)
# Processed grid point: lat index=46, lon index=28, significance=(True, False)
# Processed grid point: lat index=46, lon index=29, significance=(True, False)
# Processed grid point: lat index=46, lon index=30, significance=(False, False)
# Processed grid point: lat index=46, lon index=31, significance=(True, False)
# Processed grid point: lat index=46, lon index=32, significance=(True, False)
# Processed grid point: lat index=46, lon index=33, significance=(True, False)
# Processed grid point: lat index=46, lon index=34, significance=(True, False)
# Processed grid point: lat index=46, lon index=35, significance=(True, False)
# Processed grid point: lat index=46, lon index=36, significance=(True, True)
# Processed grid point: lat index=46, lon index=37, significance=(True, False)
# Processed grid point: lat index=46, lon index=38, significance=(True, False)
# Processed grid point: lat index=46, lon index=39, significance=(True, True)
# Processed grid point: lat index=46, lon index=40, significance=(True, False)
# Processed grid point: lat index=46, lon index=41, significance=(True, False)
# Processed grid point: lat index=46, lon index=42, significance=(True, False)
# Processed grid point: lat index=46, lon index=43, significance=(True, False)
# Processed grid point: lat index=46, lon index=44, significance=(True, True)
# Processed grid point: lat index=46, lon index=45, significance=(True, False)
# Processed grid point: lat index=46, lon index=46, significance=(True, True)
# Processed grid point: lat index=46, lon index=47, significance=(True, False)
# Processed grid point: lat index=46, lon index=48, significance=(True, True)
# Processed grid point: lat index=46, lon index=49, significance=(True, True)
# Processed grid point: lat index=46, lon index=50, significance=(True, True)
# Processed grid point: lat index=46, lon index=51, significance=(True, True)
# Processed grid point: lat index=46, lon index=52, significance=(True, False)
# Processed grid point: lat index=46, lon index=53, significance=(True, False)
# Processed grid point: lat index=46, lon index=54, significance=(True, False)
# Processed grid point: lat index=46, lon index=55, significance=(True, False)
# Processed grid point: lat index=46, lon index=56, significance=(True, False)
# Processed grid point: lat index=46, lon index=57, significance=(True, False)
# Processed grid point: lat index=46, lon index=58, significance=(True, False)
# Processed grid point: lat index=46, lon index=59, significance=(True, False)
# Processed grid point: lat index=46, lon index=60, significance=(True, False)
# Processed grid point: lat index=46, lon index=61, significance=(True, False)
# Processed grid point: lat index=46, lon index=62, significance=(True, False)
# Processed grid point: lat index=46, lon index=63, significance=(True, False)
# Processed grid point: lat index=46, lon index=64, significance=(True, False)
# Processed grid point: lat index=46, lon index=65, significance=(True, True)
# Processed grid point: lat index=46, lon index=66, significance=(True, False)
# Processed grid point: lat index=46, lon index=67, significance=(True, False)
# Processed grid point: lat index=46, lon index=68, significance=(True, False)
# Processed grid point: lat index=46, lon index=69, significance=(True, True)
# Processed grid point: lat index=46, lon index=70, significance=(True, False)
# Processed grid point: lat index=46, lon index=71, significance=(True, False)
# Processed grid point: lat index=46, lon index=72, significance=(True, False)
# Processed grid point: lat index=46, lon index=73, significance=(True, False)
# Processed grid point: lat index=46, lon index=74, significance=(True, False)
# Processed grid point: lat index=46, lon index=75, significance=(True, False)
# Processed grid point: lat index=46, lon index=76, significance=(True, False)
# Processed grid point: lat index=46, lon index=77, significance=(True, False)
# Processed grid point: lat index=46, lon index=78, significance=(True, False)
# Processed grid point: lat index=46, lon index=79, significance=(True, False)
# Processed grid point: lat index=46, lon index=80, significance=(True, False)
# Processed grid point: lat index=46, lon index=81, significance=(True, False)
# Processed grid point: lat index=46, lon index=82, significance=(True, False)
# Processed grid point: lat index=46, lon index=83, significance=(True, False)
# Processed grid point: lat index=46, lon index=84, significance=(True, False)
# Processed grid point: lat index=46, lon index=85, significance=(True, True)
# Processed grid point: lat index=46, lon index=86, significance=(True, False)
# Processed grid point: lat index=46, lon index=87, significance=(True, False)
# Processed grid point: lat index=46, lon index=88, significance=(True, False)
# Processed grid point: lat index=46, lon index=89, significance=(True, False)
# Processed grid point: lat index=46, lon index=90, significance=(True, True)
# Processed grid point: lat index=46, lon index=91, significance=(True, False)
# Processed grid point: lat index=46, lon index=92, significance=(True, False)
# Processed grid point: lat index=46, lon index=93, significance=(True, False)
# Processed grid point: lat index=46, lon index=94, significance=(True, False)
# Processed grid point: lat index=46, lon index=95, significance=(True, False)
# Processed grid point: lat index=47, lon index=0, significance=(True, True)
# Processed grid point: lat index=47, lon index=1, significance=(True, False)
# Processed grid point: lat index=47, lon index=2, significance=(True, False)
# Processed grid point: lat index=47, lon index=3, significance=(True, True)
# Processed grid point: lat index=47, lon index=4, significance=(True, False)
# Processed grid point: lat index=47, lon index=5, significance=(True, True)
# Processed grid point: lat index=47, lon index=6, significance=(True, False)
# Processed grid point: lat index=47, lon index=7, significance=(True, False)
# Processed grid point: lat index=47, lon index=8, significance=(True, False)
# Processed grid point: lat index=47, lon index=9, significance=(True, False)
# Processed grid point: lat index=47, lon index=10, significance=(True, False)
# Processed grid point: lat index=47, lon index=11, significance=(True, False)
# Processed grid point: lat index=47, lon index=12, significance=(True, False)
# Processed grid point: lat index=47, lon index=13, significance=(True, False)
# Processed grid point: lat index=47, lon index=14, significance=(True, False)
# Processed grid point: lat index=47, lon index=15, significance=(True, False)
# Processed grid point: lat index=47, lon index=16, significance=(True, True)
# Processed grid point: lat index=47, lon index=17, significance=(True, False)
# Processed grid point: lat index=47, lon index=18, significance=(True, False)
# Processed grid point: lat index=47, lon index=19, significance=(True, False)
# Processed grid point: lat index=47, lon index=20, significance=(True, False)
# Processed grid point: lat index=47, lon index=21, significance=(True, False)
# Processed grid point: lat index=47, lon index=22, significance=(True, False)
# Processed grid point: lat index=47, lon index=23, significance=(True, False)
# Processed grid point: lat index=47, lon index=24, significance=(True, False)
# Processed grid point: lat index=47, lon index=25, significance=(True, True)
# Processed grid point: lat index=47, lon index=26, significance=(True, False)
# Processed grid point: lat index=47, lon index=27, significance=(True, False)
# Processed grid point: lat index=47, lon index=28, significance=(True, False)
# Processed grid point: lat index=47, lon index=29, significance=(True, True)
# Processed grid point: lat index=47, lon index=30, significance=(True, False)
# Processed grid point: lat index=47, lon index=31, significance=(True, False)
# Processed grid point: lat index=47, lon index=32, significance=(True, True)
# Processed grid point: lat index=47, lon index=33, significance=(True, False)
# Processed grid point: lat index=47, lon index=34, significance=(True, False)
# Processed grid point: lat index=47, lon index=35, significance=(True, False)
# Processed grid point: lat index=47, lon index=36, significance=(True, True)
# Processed grid point: lat index=47, lon index=37, significance=(True, False)
# Processed grid point: lat index=47, lon index=38, significance=(True, True)
# Processed grid point: lat index=47, lon index=39, significance=(True, False)
# Processed grid point: lat index=47, lon index=40, significance=(True, False)
# Processed grid point: lat index=47, lon index=41, significance=(True, True)
# Processed grid point: lat index=47, lon index=42, significance=(True, False)
# Processed grid point: lat index=47, lon index=43, significance=(True, True)
# Processed grid point: lat index=47, lon index=44, significance=(True, False)
# Processed grid point: lat index=47, lon index=45, significance=(True, False)
# Processed grid point: lat index=47, lon index=46, significance=(True, True)
# Processed grid point: lat index=47, lon index=47, significance=(True, False)
# Processed grid point: lat index=47, lon index=48, significance=(True, False)
# Processed grid point: lat index=47, lon index=49, significance=(True, False)
# Processed grid point: lat index=47, lon index=50, significance=(True, False)
# Processed grid point: lat index=47, lon index=51, significance=(True, False)
# Processed grid point: lat index=47, lon index=52, significance=(True, True)
# Processed grid point: lat index=47, lon index=53, significance=(True, True)
# Processed grid point: lat index=47, lon index=54, significance=(True, False)
# Processed grid point: lat index=47, lon index=55, significance=(True, False)
# Processed grid point: lat index=47, lon index=56, significance=(True, True)
# Processed grid point: lat index=47, lon index=57, significance=(True, True)
# Processed grid point: lat index=47, lon index=58, significance=(True, False)
# Processed grid point: lat index=47, lon index=59, significance=(True, False)
# Processed grid point: lat index=47, lon index=60, significance=(True, False)
# Processed grid point: lat index=47, lon index=61, significance=(True, False)
# Processed grid point: lat index=47, lon index=62, significance=(True, True)
# Processed grid point: lat index=47, lon index=63, significance=(True, False)
# Processed grid point: lat index=47, lon index=64, significance=(True, False)
# Processed grid point: lat index=47, lon index=65, significance=(True, False)
# Processed grid point: lat index=47, lon index=66, significance=(True, False)
# Processed grid point: lat index=47, lon index=67, significance=(True, False)
# Processed grid point: lat index=47, lon index=68, significance=(True, False)
# Processed grid point: lat index=47, lon index=69, significance=(True, False)
# Processed grid point: lat index=47, lon index=70, significance=(True, False)
# Processed grid point: lat index=47, lon index=71, significance=(True, True)
# Processed grid point: lat index=47, lon index=72, significance=(True, False)
# Processed grid point: lat index=47, lon index=73, significance=(True, False)
# Processed grid point: lat index=47, lon index=74, significance=(True, True)
# Processed grid point: lat index=47, lon index=75, significance=(True, False)
# Processed grid point: lat index=47, lon index=76, significance=(True, False)
# Processed grid point: lat index=47, lon index=77, significance=(True, False)
# Processed grid point: lat index=47, lon index=78, significance=(True, False)
# Processed grid point: lat index=47, lon index=79, significance=(True, False)
# Processed grid point: lat index=47, lon index=80, significance=(True, False)
# Processed grid point: lat index=47, lon index=81, significance=(True, False)
# Processed grid point: lat index=47, lon index=82, significance=(True, False)
# Processed grid point: lat index=47, lon index=83, significance=(True, False)
# Processed grid point: lat index=47, lon index=84, significance=(True, False)
# Processed grid point: lat index=47, lon index=85, significance=(True, False)
# Processed grid point: lat index=47, lon index=86, significance=(True, True)
# Processed grid point: lat index=47, lon index=87, significance=(True, False)
# Processed grid point: lat index=47, lon index=88, significance=(True, False)
# Processed grid point: lat index=47, lon index=89, significance=(True, True)
# Processed grid point: lat index=47, lon index=90, significance=(True, False)
# Processed grid point: lat index=47, lon index=91, significance=(True, False)
# Processed grid point: lat index=47, lon index=92, significance=(True, False)
# Processed grid point: lat index=47, lon index=93, significance=(True, False)
# Processed grid point: lat index=47, lon index=94, significance=(True, True)
# Processed grid point: lat index=47, lon index=95, significance=(True, False)

# %%
from toolbox import significant_map as smap
import importlib
importlib.reload(smap)


df_pre_TraCE = df_pre.copy()
# crop the df_pre_all to the same time period as ds_sat_trace_all_diff
df_pre_TraCE = df_pre_TraCE[(df_pre_TraCE['age'] >= ds_sat_trace_orb_diff.age[0].values) &
                         (df_pre_TraCE['age'] <= ds_sat_trace_orb_diff.age[-1].values)]

significance_map=smap.global_ccm_significance_map(ds_sat_trace_orb_diff, df_pre_TraCE,ds_sat_ens_diff='none',
                                   E=5, tau=-4, Tp=0, libSizes="10 20 30 40 50 60 70 80",
                                   n_ran=10, sample=20, random=True, function='v3', mode='uni', show_figure=True)

import pickle
with open("output/TraCE_orb_significance_map_v3.pkl", "wb") as f:
    pickle.dump(significance_map, f)
# Out:
# Processed grid point: lat index=0, lon index=0, significance=(False, False)
# Processed grid point: lat index=0, lon index=1, significance=(False, False)
# Processed grid point: lat index=0, lon index=2, significance=(False, False)
# Processed grid point: lat index=0, lon index=3, significance=(False, False)
# Processed grid point: lat index=0, lon index=4, significance=(False, False)
# Processed grid point: lat index=0, lon index=5, significance=(False, False)
# Processed grid point: lat index=0, lon index=6, significance=(False, False)
# Processed grid point: lat index=0, lon index=7, significance=(False, False)
# Processed grid point: lat index=0, lon index=8, significance=(False, False)
# Processed grid point: lat index=0, lon index=9, significance=(False, False)
# Processed grid point: lat index=0, lon index=10, significance=(False, False)
# Processed grid point: lat index=0, lon index=11, significance=(False, False)
# Processed grid point: lat index=0, lon index=12, significance=(False, False)
# Processed grid point: lat index=0, lon index=13, significance=(False, True)
# Processed grid point: lat index=0, lon index=14, significance=(False, False)
# Processed grid point: lat index=0, lon index=15, significance=(False, False)
# Processed grid point: lat index=0, lon index=16, significance=(False, False)
# Processed grid point: lat index=0, lon index=17, significance=(False, False)
# Processed grid point: lat index=0, lon index=18, significance=(False, False)
# Processed grid point: lat index=0, lon index=19, significance=(False, False)
# Processed grid point: lat index=0, lon index=20, significance=(False, False)
# Processed grid point: lat index=0, lon index=21, significance=(False, False)
# Processed grid point: lat index=0, lon index=22, significance=(False, False)
# Processed grid point: lat index=0, lon index=23, significance=(False, False)
# Processed grid point: lat index=0, lon index=24, significance=(False, False)
# Processed grid point: lat index=0, lon index=25, significance=(False, False)
# Processed grid point: lat index=0, lon index=26, significance=(False, False)
# Processed grid point: lat index=0, lon index=27, significance=(False, False)
# Processed grid point: lat index=0, lon index=28, significance=(False, False)
# Processed grid point: lat index=0, lon index=29, significance=(False, False)
# Processed grid point: lat index=0, lon index=30, significance=(False, False)
# Processed grid point: lat index=0, lon index=31, significance=(False, False)
# Processed grid point: lat index=0, lon index=32, significance=(False, False)
# Processed grid point: lat index=0, lon index=33, significance=(False, False)
# Processed grid point: lat index=0, lon index=34, significance=(False, False)
# Processed grid point: lat index=0, lon index=35, significance=(False, False)
# Processed grid point: lat index=0, lon index=36, significance=(False, False)
# Processed grid point: lat index=0, lon index=37, significance=(False, True)
# Processed grid point: lat index=0, lon index=38, significance=(False, False)
# Processed grid point: lat index=0, lon index=39, significance=(False, False)
# Processed grid point: lat index=0, lon index=40, significance=(False, False)
# Processed grid point: lat index=0, lon index=41, significance=(False, False)
# Processed grid point: lat index=0, lon index=42, significance=(False, False)
# Processed grid point: lat index=0, lon index=43, significance=(False, False)
# Processed grid point: lat index=0, lon index=44, significance=(False, True)
# Processed grid point: lat index=0, lon index=45, significance=(False, False)
# Processed grid point: lat index=0, lon index=46, significance=(False, False)
# Processed grid point: lat index=0, lon index=47, significance=(False, False)
# Processed grid point: lat index=0, lon index=48, significance=(False, False)
# Processed grid point: lat index=0, lon index=49, significance=(False, False)
# Processed grid point: lat index=0, lon index=50, significance=(False, False)
# Processed grid point: lat index=0, lon index=51, significance=(False, True)
# Processed grid point: lat index=0, lon index=52, significance=(False, False)
# Processed grid point: lat index=0, lon index=53, significance=(False, False)
# Processed grid point: lat index=0, lon index=54, significance=(False, False)
# Processed grid point: lat index=0, lon index=55, significance=(False, False)
# Processed grid point: lat index=0, lon index=56, significance=(False, False)
# Processed grid point: lat index=0, lon index=57, significance=(False, False)
# Processed grid point: lat index=0, lon index=58, significance=(False, False)
# Processed grid point: lat index=0, lon index=59, significance=(False, False)
# Processed grid point: lat index=0, lon index=60, significance=(False, False)
# Processed grid point: lat index=0, lon index=61, significance=(False, False)
# Processed grid point: lat index=0, lon index=62, significance=(False, True)
# Processed grid point: lat index=0, lon index=63, significance=(False, False)
# Processed grid point: lat index=0, lon index=64, significance=(False, False)
# Processed grid point: lat index=0, lon index=65, significance=(False, False)
# Processed grid point: lat index=0, lon index=66, significance=(False, False)
# Processed grid point: lat index=0, lon index=67, significance=(False, False)
# Processed grid point: lat index=0, lon index=68, significance=(False, False)
# Processed grid point: lat index=0, lon index=69, significance=(False, False)
# Processed grid point: lat index=0, lon index=70, significance=(False, False)
# Processed grid point: lat index=0, lon index=71, significance=(False, False)
# Processed grid point: lat index=0, lon index=72, significance=(False, False)
# Processed grid point: lat index=0, lon index=73, significance=(False, False)
# Processed grid point: lat index=0, lon index=74, significance=(False, False)
# Processed grid point: lat index=0, lon index=75, significance=(False, False)
# Processed grid point: lat index=0, lon index=76, significance=(False, False)
# Processed grid point: lat index=0, lon index=77, significance=(False, False)
# Processed grid point: lat index=0, lon index=78, significance=(False, False)
# Processed grid point: lat index=0, lon index=79, significance=(False, False)
# Processed grid point: lat index=0, lon index=80, significance=(False, False)
# Processed grid point: lat index=0, lon index=81, significance=(False, False)
# Processed grid point: lat index=0, lon index=82, significance=(False, False)
# Processed grid point: lat index=0, lon index=83, significance=(False, False)
# Processed grid point: lat index=0, lon index=84, significance=(False, False)
# Processed grid point: lat index=0, lon index=85, significance=(False, False)
# Processed grid point: lat index=0, lon index=86, significance=(False, False)
# Processed grid point: lat index=0, lon index=87, significance=(False, False)
# Processed grid point: lat index=0, lon index=88, significance=(False, False)
# Processed grid point: lat index=0, lon index=89, significance=(False, False)
# Processed grid point: lat index=0, lon index=90, significance=(False, False)
# Processed grid point: lat index=0, lon index=91, significance=(False, False)
# Processed grid point: lat index=0, lon index=92, significance=(False, False)
# Processed grid point: lat index=0, lon index=93, significance=(False, False)
# Processed grid point: lat index=0, lon index=94, significance=(False, False)
# Processed grid point: lat index=0, lon index=95, significance=(False, False)
# Processed grid point: lat index=1, lon index=0, significance=(False, False)
# Processed grid point: lat index=1, lon index=1, significance=(False, False)
# Processed grid point: lat index=1, lon index=2, significance=(False, False)
# Processed grid point: lat index=1, lon index=3, significance=(False, False)
# Processed grid point: lat index=1, lon index=4, significance=(False, False)
# Processed grid point: lat index=1, lon index=5, significance=(False, False)
# Processed grid point: lat index=1, lon index=6, significance=(False, False)
# Processed grid point: lat index=1, lon index=7, significance=(False, False)
# Processed grid point: lat index=1, lon index=8, significance=(False, False)
# Processed grid point: lat index=1, lon index=9, significance=(False, False)
# Processed grid point: lat index=1, lon index=10, significance=(False, False)
# Processed grid point: lat index=1, lon index=11, significance=(False, False)
# Processed grid point: lat index=1, lon index=12, significance=(False, False)
# Processed grid point: lat index=1, lon index=13, significance=(False, False)
# Processed grid point: lat index=1, lon index=14, significance=(False, False)
# Processed grid point: lat index=1, lon index=15, significance=(False, False)
# Processed grid point: lat index=1, lon index=16, significance=(False, False)
# Processed grid point: lat index=1, lon index=17, significance=(False, False)
# Processed grid point: lat index=1, lon index=18, significance=(False, False)
# Processed grid point: lat index=1, lon index=19, significance=(False, False)
# Processed grid point: lat index=1, lon index=20, significance=(False, False)
# Processed grid point: lat index=1, lon index=21, significance=(False, False)
# Processed grid point: lat index=1, lon index=22, significance=(False, False)
# Processed grid point: lat index=1, lon index=23, significance=(False, False)
# Processed grid point: lat index=1, lon index=24, significance=(False, False)
# Processed grid point: lat index=1, lon index=25, significance=(False, False)
# Processed grid point: lat index=1, lon index=26, significance=(True, False)
# Processed grid point: lat index=1, lon index=27, significance=(False, False)
# Processed grid point: lat index=1, lon index=28, significance=(False, False)
# Processed grid point: lat index=1, lon index=29, significance=(False, False)
# Processed grid point: lat index=1, lon index=30, significance=(False, True)
# Processed grid point: lat index=1, lon index=31, significance=(False, False)
# Processed grid point: lat index=1, lon index=32, significance=(False, False)
# Processed grid point: lat index=1, lon index=33, significance=(False, True)
# Processed grid point: lat index=1, lon index=34, significance=(False, False)
# Processed grid point: lat index=1, lon index=35, significance=(False, False)
# Processed grid point: lat index=1, lon index=36, significance=(False, True)
# Processed grid point: lat index=1, lon index=37, significance=(False, False)
# Processed grid point: lat index=1, lon index=38, significance=(False, True)
# Processed grid point: lat index=1, lon index=39, significance=(False, False)
# Processed grid point: lat index=1, lon index=40, significance=(False, False)
# Processed grid point: lat index=1, lon index=41, significance=(False, False)
# Processed grid point: lat index=1, lon index=42, significance=(False, False)
# Processed grid point: lat index=1, lon index=43, significance=(False, False)
# Processed grid point: lat index=1, lon index=44, significance=(False, False)
# Processed grid point: lat index=1, lon index=45, significance=(False, False)
# Processed grid point: lat index=1, lon index=46, significance=(True, False)
# Processed grid point: lat index=1, lon index=47, significance=(False, False)
# Processed grid point: lat index=1, lon index=48, significance=(False, False)
# Processed grid point: lat index=1, lon index=49, significance=(False, False)
# Processed grid point: lat index=1, lon index=50, significance=(False, False)
# Processed grid point: lat index=1, lon index=51, significance=(False, False)
# Processed grid point: lat index=1, lon index=52, significance=(False, False)
# Processed grid point: lat index=1, lon index=53, significance=(False, True)
# Processed grid point: lat index=1, lon index=54, significance=(False, False)
# Processed grid point: lat index=1, lon index=55, significance=(True, True)
# Processed grid point: lat index=1, lon index=56, significance=(False, False)
# Processed grid point: lat index=1, lon index=57, significance=(False, False)
# Processed grid point: lat index=1, lon index=58, significance=(False, False)
# Processed grid point: lat index=1, lon index=59, significance=(False, False)
# Processed grid point: lat index=1, lon index=60, significance=(False, False)
# Processed grid point: lat index=1, lon index=61, significance=(False, False)
# Processed grid point: lat index=1, lon index=62, significance=(False, True)
# Processed grid point: lat index=1, lon index=63, significance=(False, False)
# Processed grid point: lat index=1, lon index=64, significance=(False, False)
# Processed grid point: lat index=1, lon index=65, significance=(False, False)
# Processed grid point: lat index=1, lon index=66, significance=(False, True)
# Processed grid point: lat index=1, lon index=67, significance=(False, False)
# Processed grid point: lat index=1, lon index=68, significance=(False, True)
# Processed grid point: lat index=1, lon index=69, significance=(False, False)
# Processed grid point: lat index=1, lon index=70, significance=(False, False)
# Processed grid point: lat index=1, lon index=71, significance=(False, False)
# Processed grid point: lat index=1, lon index=72, significance=(False, False)
# Processed grid point: lat index=1, lon index=73, significance=(False, False)
# Processed grid point: lat index=1, lon index=74, significance=(False, False)
# Processed grid point: lat index=1, lon index=75, significance=(False, False)
# Processed grid point: lat index=1, lon index=76, significance=(False, False)
# Processed grid point: lat index=1, lon index=77, significance=(False, False)
# Processed grid point: lat index=1, lon index=78, significance=(True, False)
# Processed grid point: lat index=1, lon index=79, significance=(True, False)
# Processed grid point: lat index=1, lon index=80, significance=(True, False)
# Processed grid point: lat index=1, lon index=81, significance=(True, False)
# Processed grid point: lat index=1, lon index=82, significance=(True, False)
# Processed grid point: lat index=1, lon index=83, significance=(True, False)
# Processed grid point: lat index=1, lon index=84, significance=(True, False)
# Processed grid point: lat index=1, lon index=85, significance=(True, False)
# Processed grid point: lat index=1, lon index=86, significance=(False, False)
# Processed grid point: lat index=1, lon index=87, significance=(True, False)
# Processed grid point: lat index=1, lon index=88, significance=(False, False)
# Processed grid point: lat index=1, lon index=89, significance=(False, False)
# Processed grid point: lat index=1, lon index=90, significance=(False, False)
# Processed grid point: lat index=1, lon index=91, significance=(False, False)
# Processed grid point: lat index=1, lon index=92, significance=(False, False)
# Processed grid point: lat index=1, lon index=93, significance=(False, False)
# Processed grid point: lat index=1, lon index=94, significance=(False, False)
# Processed grid point: lat index=1, lon index=95, significance=(False, False)
# Processed grid point: lat index=2, lon index=0, significance=(False, False)
# Processed grid point: lat index=2, lon index=1, significance=(False, False)
# Processed grid point: lat index=2, lon index=2, significance=(False, True)
# Processed grid point: lat index=2, lon index=3, significance=(False, False)
# Processed grid point: lat index=2, lon index=4, significance=(False, False)
# Processed grid point: lat index=2, lon index=5, significance=(False, False)
# Processed grid point: lat index=2, lon index=6, significance=(False, False)
# Processed grid point: lat index=2, lon index=7, significance=(False, False)
# Processed grid point: lat index=2, lon index=8, significance=(False, False)
# Processed grid point: lat index=2, lon index=9, significance=(False, False)
# Processed grid point: lat index=2, lon index=10, significance=(False, False)
# Processed grid point: lat index=2, lon index=11, significance=(False, False)
# Processed grid point: lat index=2, lon index=12, significance=(False, False)
# Processed grid point: lat index=2, lon index=13, significance=(False, False)
# Processed grid point: lat index=2, lon index=14, significance=(True, False)
# Processed grid point: lat index=2, lon index=15, significance=(False, False)
# Processed grid point: lat index=2, lon index=16, significance=(False, False)
# Processed grid point: lat index=2, lon index=17, significance=(False, False)
# Processed grid point: lat index=2, lon index=18, significance=(False, False)
# Processed grid point: lat index=2, lon index=19, significance=(False, False)
# Processed grid point: lat index=2, lon index=20, significance=(False, False)
# Processed grid point: lat index=2, lon index=21, significance=(False, False)
# Processed grid point: lat index=2, lon index=22, significance=(False, False)
# Processed grid point: lat index=2, lon index=23, significance=(False, False)
# Processed grid point: lat index=2, lon index=24, significance=(False, False)
# Processed grid point: lat index=2, lon index=25, significance=(False, False)
# Processed grid point: lat index=2, lon index=26, significance=(False, False)
# Processed grid point: lat index=2, lon index=27, significance=(False, False)
# Processed grid point: lat index=2, lon index=28, significance=(False, False)
# Processed grid point: lat index=2, lon index=29, significance=(False, True)
# Processed grid point: lat index=2, lon index=30, significance=(False, True)
# Processed grid point: lat index=2, lon index=31, significance=(False, True)
# Processed grid point: lat index=2, lon index=32, significance=(False, True)
# Processed grid point: lat index=2, lon index=33, significance=(False, True)
# Processed grid point: lat index=2, lon index=34, significance=(False, True)
# Processed grid point: lat index=2, lon index=35, significance=(False, False)
# Processed grid point: lat index=2, lon index=36, significance=(False, False)
# Processed grid point: lat index=2, lon index=37, significance=(False, False)
# Processed grid point: lat index=2, lon index=38, significance=(False, False)
# Processed grid point: lat index=2, lon index=39, significance=(False, False)
# Processed grid point: lat index=2, lon index=40, significance=(False, False)
# Processed grid point: lat index=2, lon index=41, significance=(False, False)
# Processed grid point: lat index=2, lon index=42, significance=(False, False)
# Processed grid point: lat index=2, lon index=43, significance=(False, False)
# Processed grid point: lat index=2, lon index=44, significance=(False, False)
# Processed grid point: lat index=2, lon index=45, significance=(False, False)
# Processed grid point: lat index=2, lon index=46, significance=(False, False)
# Processed grid point: lat index=2, lon index=47, significance=(False, False)
# Processed grid point: lat index=2, lon index=48, significance=(False, False)
# Processed grid point: lat index=2, lon index=49, significance=(False, False)
# Processed grid point: lat index=2, lon index=50, significance=(False, False)
# Processed grid point: lat index=2, lon index=51, significance=(False, False)
# Processed grid point: lat index=2, lon index=52, significance=(False, False)
# Processed grid point: lat index=2, lon index=53, significance=(False, False)
# Processed grid point: lat index=2, lon index=54, significance=(False, False)
# Processed grid point: lat index=2, lon index=55, significance=(True, False)
# Processed grid point: lat index=2, lon index=56, significance=(False, False)
# Processed grid point: lat index=2, lon index=57, significance=(True, False)
# Processed grid point: lat index=2, lon index=58, significance=(True, False)
# Processed grid point: lat index=2, lon index=59, significance=(True, False)
# Processed grid point: lat index=2, lon index=60, significance=(False, False)
# Processed grid point: lat index=2, lon index=61, significance=(True, False)
# Processed grid point: lat index=2, lon index=62, significance=(False, False)
# Processed grid point: lat index=2, lon index=63, significance=(True, True)
# Processed grid point: lat index=2, lon index=64, significance=(False, False)
# Processed grid point: lat index=2, lon index=65, significance=(False, False)
# Processed grid point: lat index=2, lon index=66, significance=(False, False)
# Processed grid point: lat index=2, lon index=67, significance=(False, False)
# Processed grid point: lat index=2, lon index=68, significance=(False, False)
# Processed grid point: lat index=2, lon index=69, significance=(False, False)
# Processed grid point: lat index=2, lon index=70, significance=(False, False)
# Processed grid point: lat index=2, lon index=71, significance=(False, False)
# Processed grid point: lat index=2, lon index=72, significance=(False, False)
# Processed grid point: lat index=2, lon index=73, significance=(False, False)
# Processed grid point: lat index=2, lon index=74, significance=(False, False)
# Processed grid point: lat index=2, lon index=75, significance=(True, False)
# Processed grid point: lat index=2, lon index=76, significance=(False, False)
# Processed grid point: lat index=2, lon index=77, significance=(True, False)
# Processed grid point: lat index=2, lon index=78, significance=(True, False)
# Processed grid point: lat index=2, lon index=79, significance=(True, False)
# Processed grid point: lat index=2, lon index=80, significance=(True, False)
# Processed grid point: lat index=2, lon index=81, significance=(True, False)
# Processed grid point: lat index=2, lon index=82, significance=(True, False)
# Processed grid point: lat index=2, lon index=83, significance=(True, False)
# Processed grid point: lat index=2, lon index=84, significance=(False, False)
# Processed grid point: lat index=2, lon index=85, significance=(False, False)
# Processed grid point: lat index=2, lon index=86, significance=(False, False)
# Processed grid point: lat index=2, lon index=87, significance=(False, False)
# Processed grid point: lat index=2, lon index=88, significance=(False, False)
# Processed grid point: lat index=2, lon index=89, significance=(False, False)
# Processed grid point: lat index=2, lon index=90, significance=(False, False)
# Processed grid point: lat index=2, lon index=91, significance=(False, False)
# Processed grid point: lat index=2, lon index=92, significance=(False, False)
# Processed grid point: lat index=2, lon index=93, significance=(False, False)
# Processed grid point: lat index=2, lon index=94, significance=(False, False)
# Processed grid point: lat index=2, lon index=95, significance=(False, False)
# Processed grid point: lat index=3, lon index=0, significance=(False, False)
# Processed grid point: lat index=3, lon index=1, significance=(False, False)
# Processed grid point: lat index=3, lon index=2, significance=(False, False)
# Processed grid point: lat index=3, lon index=3, significance=(False, True)
# Processed grid point: lat index=3, lon index=4, significance=(False, False)
# Processed grid point: lat index=3, lon index=5, significance=(False, False)
# Processed grid point: lat index=3, lon index=6, significance=(False, False)
# Processed grid point: lat index=3, lon index=7, significance=(False, False)
# Processed grid point: lat index=3, lon index=8, significance=(False, False)
# Processed grid point: lat index=3, lon index=9, significance=(False, False)
# Processed grid point: lat index=3, lon index=10, significance=(False, False)
# Processed grid point: lat index=3, lon index=11, significance=(False, False)
# Processed grid point: lat index=3, lon index=12, significance=(False, False)
# Processed grid point: lat index=3, lon index=13, significance=(False, False)
# Processed grid point: lat index=3, lon index=14, significance=(False, False)
# Processed grid point: lat index=3, lon index=15, significance=(False, False)
# Processed grid point: lat index=3, lon index=16, significance=(False, False)
# Processed grid point: lat index=3, lon index=17, significance=(False, False)
# Processed grid point: lat index=3, lon index=18, significance=(False, False)
# Processed grid point: lat index=3, lon index=19, significance=(False, True)
# Processed grid point: lat index=3, lon index=20, significance=(False, True)
# Processed grid point: lat index=3, lon index=21, significance=(False, False)
# Processed grid point: lat index=3, lon index=22, significance=(False, False)
# Processed grid point: lat index=3, lon index=23, significance=(False, False)
# Processed grid point: lat index=3, lon index=24, significance=(False, False)
# Processed grid point: lat index=3, lon index=25, significance=(False, False)
# Processed grid point: lat index=3, lon index=26, significance=(False, False)
# Processed grid point: lat index=3, lon index=27, significance=(False, False)
# Processed grid point: lat index=3, lon index=28, significance=(False, True)
# Processed grid point: lat index=3, lon index=29, significance=(False, False)
# Processed grid point: lat index=3, lon index=30, significance=(False, False)
# Processed grid point: lat index=3, lon index=31, significance=(False, False)
# Processed grid point: lat index=3, lon index=32, significance=(False, False)
# Processed grid point: lat index=3, lon index=33, significance=(False, False)
# Processed grid point: lat index=3, lon index=34, significance=(False, False)
# Processed grid point: lat index=3, lon index=35, significance=(False, False)
# Processed grid point: lat index=3, lon index=36, significance=(False, False)
# Processed grid point: lat index=3, lon index=37, significance=(False, False)
# Processed grid point: lat index=3, lon index=38, significance=(False, False)
# Processed grid point: lat index=3, lon index=39, significance=(False, False)
# Processed grid point: lat index=3, lon index=40, significance=(False, False)
# Processed grid point: lat index=3, lon index=41, significance=(False, False)
# Processed grid point: lat index=3, lon index=42, significance=(False, False)
# Processed grid point: lat index=3, lon index=43, significance=(False, False)
# Processed grid point: lat index=3, lon index=44, significance=(False, False)
# Processed grid point: lat index=3, lon index=45, significance=(False, False)
# Processed grid point: lat index=3, lon index=46, significance=(False, False)
# Processed grid point: lat index=3, lon index=47, significance=(False, False)
# Processed grid point: lat index=3, lon index=48, significance=(False, False)
# Processed grid point: lat index=3, lon index=49, significance=(False, False)
# Processed grid point: lat index=3, lon index=50, significance=(False, False)
# Processed grid point: lat index=3, lon index=51, significance=(False, False)
# Processed grid point: lat index=3, lon index=52, significance=(False, False)
# Processed grid point: lat index=3, lon index=53, significance=(False, False)
# Processed grid point: lat index=3, lon index=54, significance=(False, False)
# Processed grid point: lat index=3, lon index=55, significance=(False, False)
# Processed grid point: lat index=3, lon index=56, significance=(False, False)
# Processed grid point: lat index=3, lon index=57, significance=(False, False)
# Processed grid point: lat index=3, lon index=58, significance=(False, False)
# Processed grid point: lat index=3, lon index=59, significance=(True, False)
# Processed grid point: lat index=3, lon index=60, significance=(True, False)
# Processed grid point: lat index=3, lon index=61, significance=(True, True)
# Processed grid point: lat index=3, lon index=62, significance=(True, False)
# Processed grid point: lat index=3, lon index=63, significance=(True, False)
# Processed grid point: lat index=3, lon index=64, significance=(False, False)

# %%
from toolbox import significant_map as smap
import importlib
importlib.reload(smap)


df_pre_TraCE = df_pre.copy()
# crop the df_pre_all to the same time period as ds_sat_trace_all_diff
df_pre_TraCE = df_pre_TraCE[(df_pre_TraCE['age'] >= ds_sat_trace_fwf_diff.age[0].values) &
                         (df_pre_TraCE['age'] <= ds_sat_trace_fwf_diff.age[-1].values)]

significance_map=smap.global_ccm_significance_map(ds_sat_trace_fwf_diff, df_pre_TraCE,ds_sat_ens_diff='none',
                                   E=5, tau=-4, Tp=0, libSizes="10 20 30 40 50 60 70 80",
                                   n_ran=10, sample=20, random=True, function='v3', mode='uni', show_figure=True)

import pickle
with open("output/TraCE_orb_significance_map_v3.pkl", "wb") as f:
    pickle.dump(significance_map, f)

# %%
from toolbox import significant_map as smap
import importlib
importlib.reload(smap)


df_pre_TraCE = df_pre.copy()
# crop the df_pre_all to the same time period as ds_sat_trace_all_diff
df_pre_TraCE = df_pre_TraCE[(df_pre_TraCE['age'] >= ds_sat_trace_ghg_diff.age[0].values) &
                         (df_pre_TraCE['age'] <= ds_sat_trace_ghg_diff.age[-1].values)]

significance_map=smap.global_ccm_significance_map(ds_sat_trace_ghg_diff, df_pre_TraCE,ds_sat_ens_diff='none',
                                   E=5, tau=-4, Tp=0, libSizes="10 20 30 40 50 60 70 80",
                                   n_ran=10, sample=20, random=True, function='v3', mode='uni', show_figure=True)

import pickle
with open("output/TraCE_orb_significance_map_v3.pkl", "wb") as f:
    pickle.dump(significance_map, f)
